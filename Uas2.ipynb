# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('D:KULIAH/no2.xls')

# %%
data
# Out:
#   Category  Weather  Holiday  Game  Qty
# 0        A        5        1     0  250
# 1        B        3        1     1  200
# 2        C        1        1     0   75
# 3        D        4        1     1  400
# 4        E        4        0     0  150
# 5        F        2        0     0   50

# %%
import math 
dis = []
for i in range(6):
    dis.append(math.sqrt((float(data.iloc[i]['Weather'])-4)**2+(float(data.iloc[i]['Holiday'])- 1)**2+(float(data.iloc[i]['Game'])-1)**2))

# %%
data['dis'] = dis
data
# Out:
#   Category  Weather  Holiday  Game  Qty       dis
# 0        A        5        1     0  250  1.414214
# 1        B        3        1     1  200  1.000000
# 2        C        1        1     0   75  3.162278
# 3        D        4        1     1  400  0.000000
# 4        E        4        0     0  150  1.414214
# 5        F        2        0     0   50  2.449490
